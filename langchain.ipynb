# %%
from euriai.langchain import create_chat_model

chat_model = create_chat_model(
    api_key="euri-92b29090ad251dddaa4668a64e3209dfa5cc6b8b601e352689ced695dc636497",
    model="gpt-4.1-nano",
    temperature=0.7
)

response = chat_model.invoke("What is artificial intelligence?")
print(response.content)
# Out:
# Artificial intelligence (AI) refers to the development of computer systems and algorithms that can perform tasks typically requiring human intelligence. These tasks include learning from data (machine learning), understanding natural language (natural language processing), recognizing images or speech (computer vision), reasoning, problem-solving, and decision-making. AI aims to create systems that can adapt, improve, and perform complex functions autonomously or with minimal human intervention. It is widely applied in areas such as virtual assistants, autonomous vehicles, healthcare diagnostics, and more.

# %%
import ast, re, math, os, sys
os.environ["euri-api-key"]="euri-92b29090ad251dddaa4668a64e3209dfa5cc6b8b601e352689ced695dc636497"

from euriai.langchain import create_chat_model
from langgraph.prebuilt import create_react_agent  # Changed from langchain.agents
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser  # Fixed typo: cre -> core
from langchain_core.runnables import RunnablePassthrough, RunnableLambda, RunnableWithMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory, InMemoryChatMessageHistory as ChatMessageHistory
from langchain_core.tools import BaseTool, tool

# Note: Memory classes are deprecated in LangChain 1.0+
# Consider using RunnableWithMessageHistory instead
#from langchain.memory import (ConversationBufferMemory,ConversationBufferWindowMemory,ConversationSummaryMemory,CombinedMemory,ReadOnlySharedMemory,ConversationEntityMemory)
# Memory is now handled differently in LangChain 1.0+
# Use RunnableWithMessageHistory (already imported above) for chat memory
# Or install langchain-community for legacy memory:
# pip install langchain-community
# from langchain_community.chat_message_histories import ChatMessageHistory

# %%
pip install -U langchain langchain-core langchain-community langchain-openai
